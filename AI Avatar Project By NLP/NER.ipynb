# %%
#library for pdf files only
import PyPDF2
#library for docx files only
import docx
# importing re module
import re

# %%
# Function to extract text from a DOCX file
def extract_text_from_docx(docx_path):
    doc = docx.Document(docx_path)
    return "\n".join([para.text for para in doc.paragraphs])

# %%
# Function to extract text from a PDF file
def extract_text_from_pdf(pdf_path):
    with open(pdf_path, 'rb') as file:
        reader = PyPDF2.PdfReader(file)
        return "\n".join([page.extract_text() for page in reader.pages])

# %%
# Function to clean the extracted text but keep commas and full stops
def clean_text(text):
    # Remove special characters except commas and full stops, and reduce extra spaces
    text = re.sub(r'\s+', ' ', text)  # Replace multiple spaces/newlines with a single space
    text = re.sub(r'[^\w\s,.]', '', text)  # Keep only alphanumeric characters, commas, and full stops
    return text.strip().lower()  # Convert to lowercase and strip leading/trailing spaces

# %%
# Function to handle both file types
def extract_and_clean_text(file_path):
    if file_path.endswith('.docx'):
        extracted_text = extract_text_from_docx(file_path)
    elif file_path.endswith('.pdf'):
        extracted_text = extract_text_from_pdf(file_path)
    else:
        return "Unsupported file format."
    
    # Clean the extracted text
    return clean_text(extracted_text)

# %%
# Example usage
file_path =  'C:\\Users\\farhan\\Downloads\\AI AVATAR- MOVIE SCRIPT DATASET PDF\\AI AVATAR- MOVIE SCRIPT DATASET PDF\\AI AVATAR PROJECT MOVIE SCRIPT PDFS\\batman-begins-2005.pdf'
data = extract_and_clean_text(file_path)
print(data)
# Out:
# batman begins by david goyer black. a low keening which becomes screeching that builds and builds until red flickers through black as the screen bursts into life clouds of reeling bats silhouetted against a blood red sky, bolting away from camera, massing in the sky... forming a density the shape of an enormous batlike symbol. more bats mass, swamping the symbol, darkening the screen to black. distant childrens laughter which comes closer as sunlight flickers through black. sunlight through trees running through a summer garden. a boy. chasing a girl. the boy reaches a victorian greenhouse. stands in the doorway catching his breath. this is bruce wayne, aged 8, and we are 1 ext. gardens, wayne manor  day 1 young bruce peers down rows of plants on long trestle tables. young bruce rachel no response. sunlight streams through wrought iron and glass. young bruce advances, cautious. he is grabbed from behind and pulled under a table by a young girl, aged 10. this is rachel. she puts her hand over young bruces mouth. female voice o.s. rachel master bruce a woman strides past the windows mrs.dodson, rachels mother, housekeeper of wayne manor. young bruce whispering whatre you doing rachel matteroffact kidnapping you. they pay a lot for precious brucie. young bruce stares, wideeyed. she smiles. he relaxes. young bruce bolts out from under the trestle table  sprints for the back door. rachel tears after him. 2 ext. disused kitchen garden, wayne manor  continuous 2 young bruce crouches in the mouth of a disused well, peering over the stone wall at rachel, who searches for him. continued continued 2 2. rachel bruce, i can see you. young bruce suppresses a giggle the boards beneath him give way and he plummets into... 3 int. old well  continuous 3 young bruce drops thirty feet lands painfully on the rubble strewn bottom of the shaft. 4 ext. kitchen garden, wayne manor  continuous 4 rachel, hearing, runs to the well. rachel bruce 5 int. old well  continuous 5 young bruce lifts his head from damp dirt and rocks, groaning. 6 ext. kitchen garden, wayne manor  continuous 6 rachel sprints towards the house. rachel mom mister alfred 7 int. old well  continuous 7 young bruce, in shock, groans. he hears squealing freezes, peering into the darkness of an opening between rocks... bats explode from the darkness, filling the air. he screamscurls against their flapping, squawking, fluttering blackness. a jolt older green eyes flick open, waking... in darkness. filthy, sweating darkness... and we are in 3. 8 int. bhutanese jail  morning 8 the eyes belong to a bearded, weathered, young mans face. bruce wayne aged 28. an old asian man sits staring at him. old man a dream wayne a nightmare. old man worse than this their cell is a tin box. light seeps through gaps in the roof. shouts echo. wayne shrugs. 9 ext. prison courtyard  later 9 wayne and the old man line up for gruel. prisoners are scattered in small groups. all eyes on wayne. old man they are going to fight you. wayne i fought them yesterday. old man they will fight you every day. until they kill you. wayne holds out his plate. watches gruel dribbled onto it. wayne cant they kill me before breakfast wayne turns from the table. his path is blocked by an enormous man, backed by six aggressive prisoners. the enormous man smashes his plate away. enormous man broken english you are in hell, little man... he punches wayne wayne goes down hard. enormous man contd ...and i am the devil. wayne picks himself up. dust himself off. continued continued 2 4. wayne youre not the devil... the enormous man swings again wayne catches his fist, kicks the big mans knee out an, as he goes down, boots his face. wayne contd ...youre practice. six prisoners rush wayne all at once... wayne fights skillfully and hard, flipping one prisoner into another, kicking as his arms are held... several prisoners hit the deck before gunfire two guards break it up, shooting into the air... they grab wayne. guard solitary wayne indignan ...

# %% [markdown]
# Task 1. Entity Recognition (NER:
#
# Identify key entities such as characters, locations, dates, organizations, etc., from the movie stories.

# %%
import re
import nltk
from nltk import pos_tag, ne_chunk
from nltk.tokenize import word_tokenize

# %%
# Download NLTK resources if needed (run this once)
nltk.download('punkt')
nltk.download('maxent_ne_chunker')
nltk.download('words')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker_tab')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\farhan\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\farhan\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\farhan\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\farhan\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     C:\Users\farhan\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker_tab is already up-to-date!
# True

# %%
# Function to extract person names using NER
def extract_person_names(data):
    # Tokenize the text and tag parts of speech
    words = word_tokenize(data)
    tagged = pos_tag(words)
    
    # Perform Named Entity Recognition to identify person names
    named_entities = ne_chunk(tagged, binary=False)
    
    # Extract person names from named entities
    person_names = set()
    for chunk in named_entities:
        if hasattr(chunk, 'label') and chunk.label() == 'PERSON':
            name = ' '.join(c[0] for c in chunk)  # Join multi-word names
            person_names.add(name)
    
    return person_names

# %%
# Function to extract locations, dates, and organizations
def extract_locations_dates_orgs(data):
    # Define regex patterns for locations, dates, and organizations
    location_pattern = re.compile(r"\b(Castle|Village|Cottage|Woods|France|Villeneuve)\b", re.IGNORECASE)
    date_pattern = re.compile(r"\b(\d{1,2}(?:st|nd|rd|th)? \w+ \d{4}|\d{4})\b")  # Dates like "18th century" or specific years
    org_pattern = re.compile(r"\b(Company|Corporation|Guild|Society|Royal Guard|Army|Institute|Organization|Association)\b", re.IGNORECASE)

    # Find all locations, dates, and organizations
    locations = set(location_pattern.findall(data))
    dates = set(date_pattern.findall(data))
    organizations = set(org_pattern.findall(data))

    return {
        'locations': locations,
        'dates': dates,
        'organizations': organizations
    }

# %%
# Function to summarize extracted entities
def summarize_entities(person_names, entities):
    characters = ', '.join(person_names)
    locations = ', '.join(entities['locations'])
    dates = ', '.join(entities['dates'])
    organizations = ', '.join(entities['organizations'])
    
    summary = f"The story revolves around {characters} in {locations}. The events take place in {dates}. Key organizations include {organizations}."
    return summary

# %%
# Extract person names (characters)
person_names = extract_person_names(data)

# %%
# Extract locations, dates, and organizations
entities = extract_locations_dates_orgs(data)

# %%
# Generate summary
summary = summarize_entities(person_names, entities)
print(summary)
# Out:
# The story revolves around mr.wayne, mr.fox in . The events take place in . Key organizations include corporation, army, society, company.

# %% [markdown]
# Task 2. Dependency Parsing:
#
# Analyze the structure of sentences to understand the subject, verb, and object relationships.

# %%
import spacy

# %%
# Load the spaCy English model
nlp = spacy.load('en_core_web_sm')

# %%
def simplify_sentence(sentence):
    doc = nlp(sentence)
    simple_sentences = []
    
    # Split sentence based on main subject-verb-object clauses
    for token in doc:
        if token.dep_ == "ROOT":
            root_verb = token
            subject = [w for w in token.lefts if w.dep_ in ("nsubj", "nsubjpass")]
            objects = [w for w in token.rights if w.dep_ in ("dobj", "attr", "prep", "pobj")]
            
            # Construct simple sentences with subject-verb-object
            if subject and objects:
                subject_text = ' '.join([w.text for w in subject])
                object_text = ' '.join([w.text for w in objects])
                simple_sentences.append(f"{subject_text} {root_verb.text} {object_text}.")
            elif subject:
                subject_text = ' '.join([w.text for w in subject])
                simple_sentences.append(f"{subject_text} {root_verb.text}.")
            else:
                simple_sentences.append(f"{root_verb.text}.")
    
    return simple_sentences

# %%
# Function to break down complex text into simpler sentences
def simplify_text(data):
    doc = nlp(data)
    simple_sentences = []
    
    # Process each sentence individually
    for sentence in doc.sents:
        simplified = simplify_sentence(sentence.text)
        simple_sentences.extend(simplified)
    
    return ' '.join(simple_sentences)

# %%
# Simplify the text
simplified_text = simplify_text(data)
print(simplified_text)
# Out:
# batman begins by. keening screeching. bats mass. laughter. sunlight. boy. chasing. boy reaches greenhouse. stands. this is wayne. gardens bruce peers. rachel. sunlight streams through. advances. he grabbed from. this is rachel. she puts hand over. bruce strides past. whispering. they pay lot. stares wideeyed. she smiles. he relaxes. bolts. tears. ext. disused. i see you. suppresses. bruce drops lands. ext. garden manor runs to. bruce. old bruce lifts head from. ext. garden. mister alfred int. bruce groans. he hears. bats explode from. he screamscurls against. jolt flick. darkness. eyes belong to. wayne aged. man sits. man wayne nightmare. man cell is box. light seeps through in. shouts. shrugs. courtyard line for. prisoners scattered in. eyes. man. i fought them. man. they kill you. wayne holds plate. gruel dribbled onto. wayne they kill me. path blocked. man smashes plate. he punches wayne. man contd. wayne picks himself. dust. continued continued. you re devil. boots. you re practice. they grab wayne. indignant. i need protection. guard points at. protection. int. wayne tossed into. slams. o.s. i wonder at. voice is. european. it comes from. i thought. wayne make profile. continued continued. man. reacts. man steps into. wayne name is. i speak for. some swear. smiles ghul uses theatricality as. wayne. looks. you escaped notice. waynes. ghul offer path. code are criminals. gestures put in. nods. continued continued. ducard contd. code respects. are. knocks. it opened. is. you released. pick. you find. wayne. purpose. slams shut wayne in. bottom waynes silence. bruce lies. bruce looks figure. ext. gardens thomas carries son towards. man coils. we needing ambulance thomas. take. continued continued. they pass rachel. int. hall thomas carries bruce. house is. bruces appears at. hell be. int. bedroom looks at. alfred took fall. manages. alfred reaches to. bruce says nothing. alfred. smiles. pulls. foothills. approaches. picks. studies. ext. hamlet wanders street. locals see him. doors slammed. o.s. one help you. wayne turns. points. man appears at. i need food. man turn. wayne looks at. carries. ext. he clears ridge. ext. wayne climbs up to. unwraps. pounds knocks. nothing. wayne lowers forehead to. noise. wayne stops. doors swing. hall. wayne pulls at. he starts. sits. continued continued. swords drawn ninjas. wayne freezes. wait. warriors hold. wayne looks at. wayne reaches into. pulls. holds. ghul starts. translates. fear been guide. you advance. we help. you renounce cities. you live in. you be member. you be without. ducard takes flower. considers. contd are. wayne looks at. wayne. i. kicks. crawls. ducard strikes him in. death is. death is opponent. continued continued. ducard turns whips. he stares at. smiles. wayne rises. assumes. blocks smiles. ducards wayne falters. contd. ducard smashes him in. slams waynes chin. ducard contd. looks. curious. ducard pulls flower from. tell. eyes open. bedroom waynes memory20 bruce. cuts. he looks to. thomas is. thomas gentle bats. approaches. sits. they were. are. bruce smiles ones. thomas. thinks. you tell anyone. thomas pulls case. he opens. thomas contd for. grins. winks snaps. int. bruce watches glory. parents dressed martha. she smiles at. dad thomas. it was time. thomas draws circle in. thomas contd system. thomas draws spokes through. thomas taps diagram at. thomas contd. ext. gotham continuous 22. int. station. he looks through. tower rises. house. bruce. birds descend. stares. bats explode from. bruce starts. continued continued. looks. he grabs arm. we go stares at. martha looks. bruce looks at. nods. apologies waynes emerge from. crouches tries. he stares. he s. martha looks. thomas gives look. thomas contd. bruce looks at. smiles. come. thomas ushers family down. figure emerges from in. man. with. shifting. wallet take it. continued continued. hands reaches for. man jerks gun at. stares. thomas contd. man grabs at. it falls. man glances at. thomas contd tone fine. thomas co ...

# %% [markdown]
# Task 3. Summarization:
#
# Extract key points or sentences from the movie story for concise narration

# %%
from sumy.parsers.plaintext import PlaintextParser
from sumy.nlp.tokenizers import Tokenizer
from sumy.summarizers.text_rank import TextRankSummarizer

# %%
def sumy_summarize_text(data):
    parser = PlaintextParser.from_string(data, Tokenizer("english"))
    summarizer = TextRankSummarizer()
    
    # Generate a summary of 5 sentences (you can adjust this number)
    summary = summarizer(parser.document, 5)
    
    # Combine the summary sentences into a single string
    summary_sentences = [str(sentence) for sentence in summary]
    return " ".join(summary_sentences)

# %%
# Summarize the movie plot
summary = sumy_summarize_text(data)
print("Summary of the plot (Sumy):\n", summary)
# Out:
# Summary of the plot (Sumy):
#  peers inside... bats explode from the box, filling the air wayne dives away from the box, staring up at the squawking bats flinching... ducard leaps at wayne, who rolls sideways, blocking wayne turns to face ducard, but he is lost in the ninjas, bats filling the air, wayne flinching with their attacks... wayne stays low, slashes the arm of the ninja nearest him the man does not move. wayne strikes ducard in the head with the butt of his sword, douses his mask in the liquid fire and tosses it back into the mezzanine where the explosive powders are stored... ras leaps from his throne, striking at wayne with his sword wayne parries explosions roar from the balcony, shooting flame across the ceiling ras and wayne fight as explosions surround them... wayne leaps clear as flaming debris collapses onto ras, crushing him... the flames are rising, ninja bodies are strewn around, fresh explosions rip across the hall as ninjas flee and wayne spots ducard lying unconscious. warehouse, the narrows  continuous 151 batman smashes through the window, cloak ablaze... falling... tries to activate his cloak but only gets one side to pop open... the deployed wing causes him to spiral insert cut young bruce falling, falling in the well shaft batman plummets, trailing flame, unopened wing fluttering with the violent flapping of bats screeching, flapping, fluttering darkness... batmans stiff wing hooks a railing slows him with a joltrips dropping him to the ground with a crash... young bruce hits the dirt at the bottom of the shaft ...and a sizzle, as wet pavement damps the flames, groaning, batman rolls his burning batsuit along the asphalt. bath house, arkham asylum  continuous 266 gordon and his men appear at the door to the room the ninjaswats are moving the emitter through the hole in the wall gordon opens fire the first ninjaswat turns to the second, signals... the second ninjaswat activates the emitter a pulse of energy ripples from the machine... pipestapsdrains explode with pressurized steam gordon dives for cover 267 ext. a curve in the truck sends batman swinging up into the glass facade of a building, smashing along through forty feet of plate glass... he clears the glass, looks ahead sees the truck in his path, weapons trained on him... the machine guns open up the trigger of the rpg is squeezed blam with a shudder the truck is knocked sideways by a speeding unmarked sedan the grenade misfires into the cab... gordon is at the wheel of the unmarked sedan he ducks down the truck explodes... batman flies through the flames... on the other side, the track dead ends at another tunnel... gordon looks up in time to see batman latch the grappling gun into his belt shoot up, skirting the lip of the tunnel... 311 int.

# %% [markdown]
# 4. Topic Modeling:
#
# Identify the main themes or topics present in the story using techniques like keyword extraction.
#
# Expected Output: Themes or keywords associated with different sections of the story.

# %%
import spacy
import gensim
from gensim import corpora
from nltk.corpus import stopwords
from pprint import pprint

# %%
# Download NLTK stopwords if you haven't already
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\farhan\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Load spaCy's English model
nlp = spacy.load('en_core_web_sm')

# %%
# Preprocessing the text (Tokenize, remove stopwords, and lemmatize)
def preprocess_text(text):
    stop_words = set(stopwords.words('english'))
    doc = nlp(text.lower())  # Convert to lowercase and tokenize
    tokens = [token.lemma_ for token in doc if token.text not in stop_words and not token.is_punct]
    return tokens

# %%
# Preprocess the input text
tokens = preprocess_text(data)

# %%
# Create a dictionary and corpus for LDA
dictionary = corpora.Dictionary([tokens])
corpus = [dictionary.doc2bow(tokens)]

# %%
# Train the LDA model (you can adjust the number of topics)
lda_model = gensim.models.LdaModel(corpus=corpus, num_topics=3, id2word=dictionary, passes=10)

# %%
# Function to format topics for better readability
def format_topics(lda_model):
    topics = lda_model.print_topics(num_words=5)
    formatted_topics = []
    
    for topic_num, topic in topics:
        # Extract the keywords from the topic string
        keywords = [word.split('*')[1].replace('"', '').strip() for word in topic.split('+')]
        topic_description = f"Topic {topic_num + 1}: This section of the story focuses on themes related to {', '.join(keywords)}."
        formatted_topics.append(topic_description)
    
    return formatted_topics

# %%
# Get and print the formatted topics
formatted_topics = format_topics(lda_model)
for topic in formatted_topics:
    print(topic)
# Out:
# Topic 1: This section of the story focuses on themes related to wayne, , continuous, bruce, gordon.
# Topic 2: This section of the story focuses on themes related to wayne, , bruce, rachel, int.
# Topic 3: This section of the story focuses on themes related to wayne, , rachel, bruce, batman.

# %% [markdown]
# 5. Sentiment Analysis:
#
# Gauge the emotions or sentiment expressed in different parts of the movie story.
#
# Expected Output: Annotated text sections indicating positive, negative, or neutral sentiments.
#
# Example: “John was happy to reunite with his sister. However, the tragedy of war loomed over them.”

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
# Load the small English model for spaCy
nlp = spacy.load('en_core_web_sm')

# %%
# Function to perform sentiment analysis using VADER
def sentiment_analysis(text):
    analyzer = SentimentIntensityAnalyzer()
    doc = nlp(data)  # Process text with spaCy
    results = []

    # Analyze sentiment sentence by sentence
    for sentence in doc.sents:
        sentiment = analyzer.polarity_scores(sentence.text)
        if sentiment['compound'] >= 0.05:
            label = 'Positive'
        elif sentiment['compound'] <= -0.05:
            label = 'Negative'
        else:
            label = 'Neutral'
        
        # Store the sentence with its sentiment label
        results.append((sentence.text, label))
    
    return results

# %%
# Analyze sentiment in the movie story
sentiments = sentiment_analysis(data)

# %%
# Print annotated text with sentiment labels
print("Sentiment Analysis of the story:")
for sentence, sentiment in sentiments:
    print(f"{sentence} --> {sentiment}")
# Out:
# Sentiment Analysis of the story:
# batman begins by david goyer black. --> Neutral
# a low keening which becomes screeching that builds and builds until red flickers through black as the screen bursts into life clouds of reeling bats silhouetted against a blood red sky, bolting away from camera, massing in the sky... forming a density the shape of an enormous batlike symbol. --> Negative
# more bats mass, swamping the symbol, darkening the screen to black. --> Neutral
# distant childrens laughter which comes closer as sunlight flickers through black. --> Positive
# sunlight through trees running through a summer garden. --> Neutral
# a boy. --> Neutral
# chasing a girl. --> Neutral
# the boy reaches a victorian greenhouse. --> Positive
# stands in the doorway catching his breath. --> Neutral
# this is bruce wayne, aged 8, and we are 1 ext. --> Neutral
# gardens, wayne manor  day 1 young bruce peers down rows of plants on long trestle tables. --> Neutral
# young bruce rachel no response. --> Negative
# sunlight streams through wrought iron and glass. --> Neutral
# young bruce advances, cautious. --> Negative
# he is grabbed from behind and pulled under a table by a young girl, aged 10. --> Neutral
# this is rachel. --> Neutral
# she puts her hand over young bruces mouth. --> Positive
# female voice o.s. rachel master bruce a woman strides past the windows mrs.dodson, rachels mother, housekeeper of wayne manor. --> Neutral
# young bruce whispering whatre you doing rachel matteroffact kidnapping you. --> Neutral
# they pay a lot for precious brucie. --> Positive
# young bruce stares, wideeyed. --> Neutral
# she smiles. --> Positive
# he relaxes. --> Positive
# young bruce bolts out from under the trestle table  sprints for the back door. --> Neutral
# rachel tears after him. --> Negative
# 2 ext. --> Neutral
# disused kitchen garden, wayne manor  continuous 2 young bruce crouches in the mouth of a disused well, peering over the stone wall at rachel, who searches for him. --> Positive
# continued continued 2 2. rachel bruce, i can see you. --> Neutral
# young bruce suppresses a giggle the boards beneath him give way and he plummets into... 3 int. --> Positive
# old well  continuous 3 young bruce drops thirty feet lands painfully on the rubble strewn bottom of the shaft. --> Negative
# 4 ext. --> Neutral
# kitchen garden, wayne manor  continuous 4 rachel, hearing, runs to the well. --> Positive
# rachel bruce 5 int. --> Neutral
# old well  continuous 5 young bruce lifts his head from damp dirt and rocks, groaning. --> Negative
# 6 ext. --> Neutral
# kitchen garden, wayne manor  continuous 6 rachel sprints towards the house. --> Neutral
# rachel mom mister alfred 7 int. --> Neutral
# old well  continuous 7 young bruce, in shock, groans. --> Negative
# he hears squealing freezes, peering into the darkness of an opening between rocks... --> Negative
# bats explode from the darkness, filling the air. --> Negative
# he screamscurls against their flapping, squawking, fluttering blackness. --> Neutral
# a jolt older green eyes flick open, waking... in darkness. --> Negative
# filthy, sweating darkness... and we are in 3. 8 int. --> Negative
# bhutanese jail  morning 8 the eyes belong to a bearded, weathered, young mans face. --> Neutral
# bruce wayne aged 28. --> Neutral
# an old asian man sits staring at him. --> Neutral
# old man a dream wayne a nightmare. --> Positive
# old man worse than this their cell is a tin box. --> Negative
# light seeps through gaps in the roof. --> Neutral
# shouts echo. --> Neutral
# wayne shrugs. --> Neutral
# 9 ext. prison courtyard  later 9 wayne and the old man line up for gruel. --> Negative
# prisoners are scattered in small groups. --> Negative
# all eyes on wayne. --> Neutral
# old man they are going to fight you. --> Negative
# wayne i fought them yesterday. --> Negative
# old man they will fight you every day. --> Negative
# until they kill you. --> Negative
# wayne holds out his plate. --> Neutral
# watches gruel dribbled onto it. --> Neutral
# wayne cant they kill me before breakfast wayne turns from the table. --> Positive
# his path is blocked by an enormous man, backed by six aggressive prisoners. --> Negative
# the enormous man smashes his plate away. --> Neutral
# enormous man broken english you are in hell, little man... he punches wayne wayne goes down hard. --> Negative
# enormous man contd ...and i am the devil. --> Negative
# wayne picks himself up. --> Neutral
# dust himself off. --> Neutral
# continued continued 2 4. --> Neutral
# wayne youre not the devil... --> Positive
# the enormous man swings again wayne catches his fist, kicks the big mans knee out an, as he goes down, boots his face. --> Neutral
# wayne contd ...youre practice. --> Neutral
# six prisoners rush wayne all at once... wayne fights skillfully and hard, flipping one prisoner into another, kicking as his arms are held... several prisoners hit the deck before gunfire two guards break it up, shooting into the air... they grab wayne. --> Negative
# guard solitary wayne indignant why guard for protection. --> Negative
# wayne i dont need protection. --> Neutral
# the guard points angrily at the unconscious prisoners. --> Negative
# guard protection for them. --> Neutral
# 10 int. --> Neutral
# solitary, bhutanese jail  moments later 10 wayne is tossed into the dark cell. --> Neutral
# the door slams. --> Neutral
# voice o.s. --> Neutral
# i often wonder at the riches to be found in dark places. --> Positive
# the voice is mellifluous. --> Neutral
# european. --> Neutral
# it comes from the shadows of a deep corner of the cell. --> Neutral
# wayne i thought the point of solitary confinement was the solitary part. --> Neutral
# wayne can make out the profile of a man seated in the corner. --> Neutral
# continued continued 2 5. --> Neutral
# man these men have mistaken you for a criminal, mr.wayne ... --> Negative
# wayne reacts to his name. --> Neutral
# the man steps into the light powerfullybuilt, distinguished, in a wellcut suit and tie. --> Neutral
# wayne who are you man my name is merely ducard. --> Neutral
# but i speak for ras al ghul. --> Neutral
# have you heard the name wayne ive heard the legends...master warrior, international mercenary, feared by all the underworld... some even swear hes immortal. --> Negative
# ducard smiles ras al ghul uses theatricality and deception as powerful weapons. --> Neutral
# ducard approaches wayne. --> Neutral
# looks deep into his eyes. --> Neutral
# ducard contd you have not escaped his notice a man like you is here by choice... or because he is truly lost . --> Positive
# waynes eyes flick away from ducards penetrating gaze. --> Neutral
# ducard contd ras al ghul and his league of shadows offer a path to those that are capable of upholding our code. --> Positive
# wayne code arent you criminals ducard a criminal is simply a man that someone else thinks... --> Negative
# gestures around them ... should be put in jail. --> Neutral
# wayne nods, conceding the point. --> Neutral
# continued continued 3 6. --> Neutral
# ducard contd this world is run by tyrants and corrupt bureaucrats. --> Neutral
# our code respects only the natural order of things were not bound by their hypocrisy. --> Positive
# are you ducard moves to the door. --> Neutral
# knocks. --> Neutral
# it is opened by a guard. --> Neutral
# ducard contd there is a rare flower a blue doublebloomed poppy that grows on the eastern slopes. --> Neutral
# tomorrow you will be released. --> Neutral
# pick one of the flowers. --> Neutral
# if you can carry it to the top of the mountain, you may find what you are looking for. --> Positive
# wayne and what am i looking for ducard looks at wayne with a glint in his eye. --> Neutral
# ducard purpose. --> Neutral
# the door slams shut leaving wayne in darkness... 11 int. --> Negative
# bottom of the old well  day waynes memory 11 silence. --> Positive
# young bruce lies there, exhausted, weeping softly. --> Negative
# male voice bruce young bruce looks up a figure, long coat billowing, is lowered down the shaft... thomas wayne, young bruces father. --> Negative
# 12 ext. --> Neutral
# gardens, wayne manor  moments later 12 thomas carries his son towards the house. --> Neutral
# at his side, a 50 yearold man in a somber suit calmly coils a rope alfred. --> Negative
# alfred will we be needing an ambulance, master wayne thomas we have everything i need to set the bone. --> Neutral
# ill take him for xrays later. --> Negative
# continued continued 2 7. alfred very good, sir. --> Positive
# they pass a tearful rachel standing with her mother. --> Neutral
# 13 int. --> Neutral
# hall, wayne manor  continuous 13 thomas carries bruce up the main stairs. --> Neutral
# the house is vast and grand, but full of flowers and life. --> Positive
# bruces mother martha appears at the landing, distraught. --> Negative
# thomas reassuring hell be fine. --> Negative
# 14 int. --> Neutral
# bruces bedroom, wayne manor  later 14 alfred moves to the bedside. looks down at young bruce. --> Neutral
# alfred took quite a fall, didnt we young bruce looks up at alfred. --> Neutral
# manages a slight smile. --> Positive
# alfred and why do we fall, master bruce alfred reaches up to the curtains. --> Positive
# young bruce says nothing. --> Neutral
# alfred so that we might better learn to pick ourselves up. --> Positive
# alfred smiles gently. --> Positive
# pulls the curtains shut, and we cut to an exquisite doublebloomed blue poppy... and we are 15 ext. --> Negative
# himalayan foothills  day 15 a field of the blue poppies. --> Neutral
# wayne approaches. --> Neutral
# picks one. --> Neutral
# studies its brilliant blue in the cold sunshine. --> Positive
# 8. 16 ext. --> Neutral
# tiny hamlet, himalayas  day 16 wayne, exhausted, freezing, hungry, wanders up the street. --> Negative
# as locals see him they head inside. --> Neutral
# doors slammed, bolted. --> Neutral
# child o.s. --> Neutral
# no one will help you. --> Positive
# wayne turns to find a young child staring at him. --> Neutral
# the child points at the blue flower pinned to waynes chest. --> Neutral
# an old man appears at the childs side. --> Neutral
# wayne weak i need food. --> Negative
# old man then turn back. --> Neutral
# wayne looks at the old man. --> Neutral
# then carries on up the mountain. --> Neutral
# 17 ext. mountain  day 17 wayne, struggles through driving snow up an icy ridge... he clears the ridge, flops down into the snow, painfully raises his scarfwrapped face to the cutting wind to see a monastery perched on jagged rock. --> Negative
# 18 ext. --> Neutral
# himalayan fortified monastery  day 18 wayne climbs up the steps to the vast doors of the monastery. --> Neutral
# unwraps a severely frostbitten fist. --> Negative
# pounds against the icecovered wood, knocks echoing deep within. --> Neutral
# nothing. --> Neutral
# wayne lowers his forehead to the door, shoulders wracked by sobs, pounding accelerating to a frenzy. --> Negative
# a grinding noise from within. --> Neutral
# wayne stops, straightens. --> Negative
# the doors swing open to darkness... 19 int. --> Negative
# great hall, monastery  continuous 19 wayne shuffles forward into a lowceilinged wooden hall lit by flickering lamps. --> Positive
# hands trembling, wayne pulls at brittle scarves. --> Negative
# he starts as the doors thud shut behind him. --> Neutral
# at the far end, on a raised platform, sits a dark robbed figure ras al ghul. --> Neutral
# wayne moves unsteadily towards him... continued continued 2 9. --> Neutral
# wayne hoarse ras al ghul armed warriors of various races emerge from the shadows bows taut, swords drawn... ninjas. --> Neutral
# wayne freezes. --> Neutral
# ducard o.s. wait. --> Neutral
# the warriors hold. --> Neutral
# wayne looks at the source of the command ducard leans against a nearby pillar. --> Neutral
# wayne reaches into his layers of clothing. --> Positive
# pulls out the doublebloomed blue poppy. --> Neutral
# holds it out, shaking. --> Negative
# ras al ghul starts to speak in urdu. --> Neutral
# ducard translates. --> Neutral
# ducard fear has been your guide. --> Negative
# but now you must advance or fear will keep you on your knees. --> Negative
# we will help you conquer your fear. --> Negative
# in exchange you will renounce the cities of man. --> Neutral
# you will live in solitude. --> Neutral
# you will be a member of the leagues of shadows. --> Neutral
# and you will be without fear. --> Positive
# ducard takes the flower. --> Neutral
# considers its delicate blue petals. --> Positive
# ducard contd are you ready to begin ducard threads the flower through the buttonhole of his lapel. --> Positive
# wayne looks at ducard, shaking with hunger and fatigue. --> Negative
# wayne ready --> Positive
# i... --> Neutral
# i can barely ducard kicks him wayne crashes to the floor. --> Neutral
# ducard death does not wait for you to be ready... wayne crawls, gasping. --> Negative
# ducard strikes him in the ribs. --> Negative
# ducard contd death is not considerate, or fair. --> Negative
# and make no mistake today, death is your opponent. --> Negative
# continued continued 3 10. --> Neutral
# ducard turns whips his leg in a fearsome roundhouse kick aimed straight at waynes neck but wayne blocks the kick with a lateral movement of his forearm. --> Negative
# he stares at ducard, eyes blazing. --> Neutral
# ducard smiles. --> Positive
# wayne rises. --> Neutral
# assumes a martial stance. --> Neutral
# ducard strikeswayne blocks and parries, driving his body through pain into a series of fluid, skilled moves... ducard contd tiger crane... ju jitsu... smiles skilled. --> Negative
# but this is not a dance ducard grapples wayne, brawling, biting, energized, messy... ducard contd facing death you learn the truth... ducards head smashes waynes cheek wayne falters ducard --> Negative
# contd --> Neutral
# you are weak... ducard smashes him in the groin. --> Negative
# ducard contd you are alone... ducard slams waynes chin, sends him down hard. --> Negative
# ducard contd and you are afraid... ducard crouches at waynes side. --> Neutral
# looks into his glazed eyes. --> Neutral
# ducard contd curious but not of me . --> Positive
# ducard pulls the flower from his lapel. --> Neutral
# leans in close to replace it on waynes chest, his lips at waynes ear... ducard contd tell us, wayne... violent flapping, screeching black rats swarming, chittering ducard v.o. whispers what do you fear 11. --> Negative
# young bruces eyes open, and we are 20 int. --> Neutral
# bruces bedroom, wayne manor  dawn waynes memory20 young bruce, breathing hard. --> Negative
# light cuts across the bedclothes. --> Negative
# he looks to the door. --> Neutral
# wayne manor  later 28 mourners file towards the gates. --> Negative
# rachel walks with her mother. --> Neutral
# looks up at bruces high window. --> Neutral
# sees him watching. --> Neutral
# waves. --> Neutral
# young bruce pauses, then returns the wave. --> Neutral
# 29 int. --> Neutral
# bruces bedroom  continuous 29 alfred enters. --> Neutral
# looks tenderly at young bruces back. --> Positive
# alfred i thought id prepare a little supper. --> Neutral
# no response. --> Negative
# alfred turns. --> Neutral
# alfred contd very well. --> Positive
# young bruce o.s. alfred alfred turns back. --> Neutral
# young bruce is looking at him with tears pouring down his cheeks. --> Negative
# alfred tilts his head. --> Neutral
# alfred voice catching master bruce young bruce it was my fault, alfred. --> Negative
# alfreds mouth opens. --> Neutral
# young bruce contd i made them leave the theater alfred --> Negative
# oh, no, no, no alfred moves to young bruce, taking the boy in his arms. --> Negative
# young bruce if i hadnt got scared alfred no, no, master bruce. --> Positive
# nothing you did. --> Neutral
# nothing anyone ever did can excuse that man. --> Positive
# continued continued 2 17. --> Neutral
# alfred holds young bruce away to look directly into his eyes. --> Neutral
# alfred contd its his, and his alone. --> Negative
# do you understand young bruce nods. --> Neutral
# then buries his face in alfreds chest, sobbing. --> Negative
# young bruce --> Neutral
# i miss them, alfred. --> Negative
# i miss them so much. --> Negative
# alfred whispering so do i, master bruce. --> Neutral
# so do i. tears well in alfreds eyes as he holds the boy, watching snowflakes swirl past the window. --> Neutral
# ducard v.o. --> Neutral
# and do you still feel responsible 30 int. --> Positive
# passageway, monastery  day 30 ducard leads wayne along a screened passage overlooking extraordinary mountains. --> Neutral
# wayne my anger outweighs my guilt. --> Negative
# ducard opens a door... 31 int. --> Neutral
# dojo, monastery  day 31 leads wayne onto a mezzanine level stacked with boxes and bottles. --> Neutral
# ninjas pour powders into packets, mixing compounds. --> Neutral
# ducard takes a pinch of a powder throws it down bang wayne flinches ducard smiles goodnaturedly. --> Positive
# ducard advanced techniques of ninjitsu employ explosive powders. --> Positive
# wayne as weapons ducard or distractions. --> Negative
# theatricality and deception are powerful agents. --> Neutral
# continued continued 2 18. --> Neutral
# ducard hands wayne a pinch of the powder. --> Neutral
# ducard contd to be a great warrior is not enough. --> Positive
# flesh and blood, however skilled, can be destroyed... --> Negative
# you must be more than just a man in the minds of your opponents. --> Neutral
# wayne listens to this. --> Neutral
# tosses the powder bang 32 ext. --> Neutral
# frozen lake, himalayas  day 32 wayne and ducard circle each other on the ice, swords poised to strike. --> Positive
# dark figures in the white and blue landscape. --> Neutral
# ducard strikes at wayne, who deflects the blow using a silver gauntlet with three scallops thick, hooklike projections. --> Negative
# ducard skids left, breath steaming, feinting with his sword. --> Neutral
# wayne steps sideways on the ice, his foot landing on a thin patch which creaks, water bubbling underneath. --> Neutral
# ducard mind your surrounding. --> Neutral
# always. --> Neutral
# wayne strikes ducard blocks with his own bronze gauntlet. --> Negative
# wayne slips right and flies in with a short thrust ducards arm flips down in a backhand move ducard catches waynes sword in one of his scallops. --> Neutral
# ducard contd your parents death was not your fault... --> Negative
# ducard rotates his arm, wrenching waynes sword from his grasp it skids along the ice. --> Neutral
# ducard contd ...it was your fathers. --> Neutral
# wayne, enrages, dives at ducard, swinging at him with the scallops, furious, reckless. --> Negative
# ducard parries with his sword, they lock noses inches apart, wayne breathing... angry... ducard contd anger does not change the fact that your father failed to act. --> Negative
# continued continued 2 19. --> Neutral
# wayne the man had a gun ducard would that stop you wayne ive had training ducard the training is nothing. --> Negative
# the will to take control is everything. --> Neutral
# your father trusted his city, its logic... --> Positive
# he thought he understood the attacker and could simply give him what he wanted... wayne considers this... breathing slowing... --> Negative
# calmer... --> Positive
# they separate. --> Neutral
# ducard contd gently your father did not understand the forces of decay cities like gotham are in their death throes chaotic, grotesque. --> Negative
# beyond saving. --> Neutral
# wayne beyond saving you believe that ducard regards the harshly beautiful landscape. --> Positive
# ducard it is not right that one must come so far to see the world as it is meant to be. --> Neutral
# purity. --> Neutral
# serenity... solitude. --> Neutral
# these are the qualities we hold dear. --> Positive
# but the important thing is whether you believe it... wayne stares at ducard. --> Positive
# ducard contd can gotham can be saved, or is she an ailing ancestor whose time has run ducard strikes down at wayne with his sword. --> Positive
# wayne blocks the strike with forearms crossed, slides between ducards legs across the ice to where his sword lies. --> Negative
# grasping his sword he spins, sweeping at ducards feet. --> Neutral
# ducard leaps wayne catches his foot, brings him down onto the ice. --> Neutral
# wayne thrusts his sword at ducards throat continued continued 3 20. --> Neutral
# stops inches from ducards bare neck. --> Negative
# ducard freezes, arms at his sides. --> Neutral
# wayne looks down at ducard, smiling in triumph. --> Positive
# wayne yield. --> Neutral
# ducard smiles. --> Positive
# shakes his head. --> Neutral
# ducard you havent beaten me. --> Positive
# youve sacrificed sure footing for a killing stroke. --> Negative
# ducard taps the ice beneath waynes feet with his sword the ice gives way, plunging wayne through the surface. --> Neutral
# 33 ext. --> Neutral
# shore, frozen lake  evening 33 ducard feeds a small fire. --> Negative
# wayne rubs his arms, shivering violently against hypothermia. --> Negative
# ducard looks at him. --> Neutral
# ducard dont rub your arms, rub your chest. --> Neutral
# your armsll take care of themselves. --> Positive
# wayne rubs his torso, nods at ducard. --> Neutral
# ducard feeds the fire. --> Negative
# ducard contd you have strength born of years of grief and anger, wayne. --> Negative
# the strength of a man denied revenge. --> Negative
# even in his shivering, wayne reacts to this. --> Neutral
# ducard contd why, wayne.. 34 int. --> Neutral
# wayne station platform  day waynes memory 34 a monorail pulls into the platform. --> Neutral
# disgorges passengers. --> Neutral
# ducard v.o. --> Neutral
# why could you not avenge your parents amongst them, bruce, aged 20, holding a bag. --> Neutral
# he sees alfred, now 62, craning his neck, searching. --> Neutral
# he waves. --> Neutral
# continued continued 2 21. --> Neutral
# bruce you didnt have to pick me up alfred well, sir, the red line... --> Positive
# well, its closed. --> Positive
# apparently mr.earle thought it wasnt making enough money. --> Neutral
# 35 int. --> Neutral
# concourse, wayne station  moments later 35 bruce looks sadly at the decay to his fathers station glass cracked, marble chipped, homeless bundled in shuttered storefronts... he looks up through the sparing glass wayne tower looms overhead, gold lettering catching the sun... --> Negative
# bruce how is mr.earle alfred --> Neutral
# oh... successful. --> Positive
# 36 int. --> Neutral
# rolls royce  later 36 alfred glances at bruce in the rearview mirror. --> Neutral
# alfred will you be heading back to princeton tomorrow or could i persuade you to spend an extra night or two bruce im not heading back at all. --> Neutral
# alfred you dont like it there bruce smiles, sardonic. --> Positive
# looks out at the trees flashing by. --> Neutral
# bruce i like it fine... --> Positive
# they just dont feel the same way. --> Neutral
# alfred purses his lips, irritated. --> Negative
# 22. 37 ext. --> Neutral
# wayne manor  moments later 37 bruce stares up at house. --> Neutral
# alfred pulls the bag out of the car and, to bruces surprise, drops it at bruces feet. --> Positive
# 38 int. --> Neutral
# wayne manor  continuous 38 alfred leads bruce up the main staircase. --> Neutral
# the house is now dark and empty. --> Negative
# dustcloths cover much of the furniture. --> Neutral
# alfred tense --> Negative
# ive prepared the master bedroom. --> Positive
# bruce my old room will be fine. --> Positive
# alfred stern with all due respect, sir, your father is dead. --> Negative
# wayne manor is your house. --> Neutral
# bruce irritated no, alfred, his isnt my house. --> Negative
# gestures its a mausoleum. --> Neutral
# a reminder of everything i lost. --> Negative
# and when i have my way ill pull the damn thing down brick by brick alfred turns on bruce, angry. --> Negative
# alfred this house, master wayne , has sheltered six generations of the wayne family, and stood patiently by while youve cavorted in and out of a dozen private schools and colleges. --> Neutral
# as have i. bruce stares at alfred. --> Neutral
# eyes burning. --> Neutral
# chastened. --> Neutral
# alfred contd softer the wayne family legacy is not so easily shrugged off. --> Negative
# bruce sadly nor borne, old friend. --> Negative
# im sorry to have disappointed you. --> Negative
# continued continued 2 23. --> Neutral
# alfred master wayne... --> Neutral
# i was at your fathers side when you were born. --> Neutral
# and at your side when he was laid to rest. --> Neutral
# bruce voice catching i know. --> Neutral
# alfred your father was a great man. --> Positive
# but i have every confidence that you will exceed his greatness. --> Positive
# bruce havent given up on me, yet alfred conviction never. --> Neutral
# bruce sags under the burden of alfreds faith. --> Neutral
# he opens the door to his bedroom, then turns back to alfred... --> Neutral
# bruce i may not get another chance to thank you for all youve done for me. --> Positive
# alfred looks at him, --> Neutral
# curious. alfred are you going away after the hearing bruce shrugs, hard to read. --> Positive
# then enters his old bedroom. --> Neutral
# 39 int. --> Neutral
# bruces bedroom  continuous 39 bruce puts his bag on the bed. --> Neutral
# looks around the room. --> Neutral
# at the mantel, bruce stares at a framed photograph young bruce on his dads shoulders, arms raised in triumph. --> Positive
# bruce wipes dust from the photograph. --> Neutral
# smiles at it. --> Positive
# insert cut young bruce on thomass shoulders thomas tips back, threatening to drop young bruce who laughs and laughs. --> Negative
# bruce moves to the bed. --> Neutral
# opens his case. --> Neutral
# inside it is a gun. --> Negative
# 24. 40 ext. --> Neutral
# gates, wayne manor  morning 40 rachel, now 23, stands by her car looking up at the house. --> Neutral
# she can see bruce in the window. --> Neutral
# she gives a small wave. --> Neutral
# 41 int. --> Neutral
# bruces bedroom  continuous 41 bruce returns rachels wave. --> Neutral
# then finishes loading his gun. --> Negative
# 42 ext. --> Neutral
# gates, wayne manor  moments later 42 bruce walks down the drive to rachel. --> Neutral
# he smiles gently. --> Positive
# opens his door. --> Neutral
# 50 ext. dock area, gotham  continuous 50 bruce watches rachels car disappear. --> Negative
# turns to look at the line of ships in the harbor. --> Neutral
# he makes his way to the water. --> Neutral
# takes out his gun. --> Negative
# turns it, studies the light off its metal insert cut the trembling barrel of chills gun, inches from thomas waynes chest. --> Negative
# bruce, with contempt, flings his gun into the black water. --> Negative
# 30. 51 ext. --> Neutral
# basement club, facing docks  later 51 bruce walks towards the entrance. --> Neutral
# a bouncer steps out, looking at him with contempt. --> Negative
# bouncer get lost, kid. --> Negative
# bruce pulls a massive wad of cash from his pocket. --> Neutral
# splits it in two. --> Neutral
# offers one half. --> Neutral
# bruce the other half when you give me the nod that falcones leaving. --> Neutral
# unawares. --> Neutral
# the bouncer looks at bruce. --> Neutral
# takes the money. --> Neutral
# 52 ext. basement club, facing docks  later 52 bruce watches the entrance from the shadows. --> Neutral
# two thugs escort a thickset man out of a club. --> Neutral
# the bouncer waves bouncer night, mr.falcone. --> Neutral
# the three men move towards a waiting limo wham one thug takes a kick to the head, goes down bruce steps from the shadows the second thug goes for his gun bruce grabs his arm chops his throat judo flips the thug... --> Negative
# bruce turns to falcone who looks at him, curious. --> Positive
# falcone the little rich kid. --> Positive
# no gun im insulted. --> Negative
# the first thug lunges at bruce with a knife bruce puts him down with a graceful sweep bruce i dont need a gun. --> Positive
# falcone yes, you do. --> Positive
# click. --> Neutral
# a gun is at bruces head. --> Negative
# held by the bouncer. --> Neutral
# continued continued 2 31. --> Neutral
# falcone contd money isnt power down here fear is. --> Negative
# the bouncer pistol whips him once, hard. --> Negative
# bruce goes down. --> Neutral
# the bouncer drops bruces money onto him. --> Neutral
# falcone contd you shoulda just sent me a thankyou note... --> Neutral
# bruce looks up at falcone. --> Neutral
# spits blood. --> Neutral
# bruce i didnt come here to thankyou. --> Neutral
# i came to show you that not everyone in gotham is afraid of you. --> Neutral
# falcone laughs just those that know me. --> Positive
# you got balls, kid... cold --> Neutral
# but you dont belong down here with us. --> Neutral
# we dont play fair. --> Negative
# now go back to your big house, wrap yourself in your silk sheets and ill send you a shoulder to cry on. --> Negative
# bruce you dont dress well enough to be a pimp. --> Negative
# falcone lights a cigar. --> Neutral
# stares down at bruce. --> Neutral
# ice. --> Neutral
# falcone you miss your mommy and daddy come down here again, i send you to them. --> Negative
# falcone turns. --> Neutral
# his thugs get into the limo with him. --> Neutral
# bruce watches it slide into the night. --> Neutral
# struggles to his feet... bruce walks the docks, wiping blood from his mouth. --> Negative
# shadows in doorways mark his progress. --> Positive
# three youths approach. --> Neutral
# bruce stiffens, but they cross the street to avoid him. --> Negative
# male voice o.s. --> Neutral
# no onell mess with ya. --> Neutral
# bruce turns. --> Neutral
# a homeless man warming at a flaming oil drum. --> Positive
# one of many homeless clustered around the docks. continued continued 3 32. --> Neutral
# homeless man wander round here dressed like that, means you got something to prove. --> Positive
# man with something to prove is dangerous. --> Negative
# bruce stares at the man. --> Neutral
# thinking. --> Neutral
# takes out his wallet. --> Neutral
# removes the money. --> Neutral
# hands it to the homeless man. --> Neutral
# homeless man contd for what bruce your jacket. --> Neutral
# bruce drops his wallet into the fire. --> Negative
# the homeless man laughs. --> Positive
# bruce pulls off his tie, throws it into the fire. --> Negative
# he pulls off his overcoat, bundles it up ready to homeless man lemme have it, thats a good coat. --> Positive
# bruce looks at the homeless man, who has removed his own. --> Neutral
# they exchange clothing. --> Neutral
# bruce be careful who sees you with that. --> Positive
# off look theyre gonna come looking for me. --> Neutral
# homeless man who bruce smiles. --> Positive
# bruce everyone. --> Neutral
# bruce, less incongruous in his new coat, moves down towards the stacks of containers... --> Neutral
# bruce wanders the stacks. --> Neutral
# a horn sounds. --> Neutral
# bruces eyes lock onto the ship preparing to leave. --> Negative
# bruce runs towards it trough the shadows... ducard o.s. --> Neutral
# and when you left gotham... --> Neutral
# and we are 33. --> Neutral
# 53 ext. --> Neutral
# himalayan monastery  day 53 ducard ...what were you seeking ducard leaps up onto a stone wall. --> Neutral
# grabbing on using pikes on his palms and on his feet. --> Neutral
# wayne watches. --> Neutral
# wayne to lose myself. --> Negative
# i couldnt do anything as bruce wayne. --> Neutral
# i felt useless. --> Negative
# ducard gestures up to the top of the 50ft wall. --> Positive
# ducard perhaps you can beat my record. --> Neutral
# bruce jumps up onto the wall, higher than ducard. --> Neutral
# confident. --> Positive
# wayne how long ducard two days. --> Neutral
# off look the test is not to see how quickly you can climb, but how slowly . --> Neutral
# the ninja is thought invisible, but invisibility is largely a matter of patience. --> Neutral
# ducard reaches up for another handhold. --> Positive
# slowly. --> Neutral
# ducard contd on your journey... you sought knowledge of the criminal world wayne nods i needed to understand the thoughts and feelings of those who stand in the shadows... cut to 54 ext. --> Negative
# crowded market, african port town  evening memory54 wayne v.o. --> Neutral
# the first time youre forced to steal not to starve... 34. --> Negative
# bruce picks up a mango from a stack to examine it. --> Neutral
# as he does so he uses his lower hand to slip a plum into his pocket. --> Positive
# 55 ext. --> Neutral
# alley, african port town  later 55 bruce squats in a doorway. --> Neutral
# bites hungrily into his plum. --> Neutral
# he looks up. --> Neutral
# a child in rags sits in the next doorway, staring. --> Neutral
# bruce stares back, juice dripping. --> Neutral
# wayne v.o. ...you lose many assumptions about the simple nature of right and wrong. --> Negative
# bruce hands the child the plum. licks his fingers. --> Neutral
# hard. --> Negative
# 56 int. --> Neutral
# train station, london  day 56 bruce bearded, filthy in a crowd, with an elderly man. --> Neutral
# wayne v.o. --> Neutral
# i needed to feel the fear before a crime... the elderly man spots a businessman hurrying along steps into his path, engineering a collision, tumbling to the pavement. --> Negative
# the businessman and bruce both crouch to help. --> Positive
# wayne v.o. contd and the thrill of success... bruce slips the businessmans wallet out of his pocket. --> Positive
# the businessman moves off. --> Neutral
# bruce shows the elderly man the wallet for approval. --> Positive
# ...
# the cloak goes rigid smashing the wind like a parachute... batmans arms control his cloak, not simply arresting his fall, but gliding gracefully like a hand glider... --> Positive
# he eyes the moving train and noses down, accelerating 301 int. --> Neutral
# monorail train  continuous 301 ras pulls off his mask, watching the city speed around him. --> Neutral
# 302 int. --> Neutral
# sedan on the bridge to the narrows  continuous 302 flass is in the drivers seat, eating. --> Neutral
# gordon opens the door grabs him flass what the flings him out onto the asphalt peels out... --> Neutral
# 120. 303 ext. --> Neutral
# gotham  continuous 303 batman streaks down, cutting through the steam geysers shooting up in the trains wake... the train speeds through a station batman banks sharply around the building... 304 int. --> Negative
# control room, water board  continuous 304 the technician stares at the map blinking lights reach closer and closer to wayne tower... --> Neutral
# second technician pressures building at the hub technician open all the runoff valves second technician theyre already blown the technician, worried, looks at a pressure gauge the needle is moving steadily higher, towards the red zone... --> Negative
# 138. 305 ext. monorail train  continuous 305 the track ahead passes into an office building batman noses down trying to get down onto the train before it reaches the building... batman gets over the back of the trainits at the mouth of the tunnel he collapses his cloak drops onto the train just as it blasts into the building 306 int. --> Negative
# train  continuous 306 ras hears a thump. --> Neutral
# he nods at his ninjas. --> Neutral
# they move into the rear car, cocking machine guns... 307 ext. --> Neutral
# train  continuous 307 batman lies on the roof the train speeds through the canyons of downtown gotham... --> Negative
# bullets tear through the roof, several hit batman jolting him loose, spinning his sideways 308 int. --> Negative
# train  continuous 308 the ninjas see a shadow fall from the roof. --> Neutral
# one of them sticks his head up to check nothing but fresh bullet holes. --> Negative
# at the ninjas feet, unnoticed, a grappling hook sticks through the floor of the train 309 ext. --> Neutral
# surface streets below the monorail  continuous 309 a small crowd outside a store watch news on stacked t.v.s. --> Neutral
# the train streaks overhead. --> Neutral
# people look up, shocked to see batman hanging from the train by his grappling cable, flying along, 15 feet in the air, dodging stoplights and awnings... the train crosses over a busy intersection batman flies over cars, between tall trucks... behind him, in the trains wake, manhole covers explode, fire hydrants burst... --> Negative
# batman struggles to fasten his grappling gun into his utility belt, but hes being tossed too violently... up ahead more of ras al ghuls ninjas ride in a truck, preceding the train, guarding the monorail supports. --> Negative
# 139. 310 ext. street below the monorail  continuous 310 in the truck, a ninja puts a rocketpropelled grenade launcher on his shoulder, sighting batman the others aim their guns. --> Neutral
# a curve in the truck sends batman swinging up into the glass facade of a building, smashing along through forty feet of plate glass... --> Neutral
# he clears the glass, looks ahead sees the truck in his path, weapons trained on him... --> Negative
# the machine guns open up the trigger of the rpg is squeezed blam with a shudder the truck is knocked sideways by a speeding unmarked sedan the grenade misfires into the cab... --> Negative
# gordon is at the wheel of the unmarked sedan he ducks down the truck explodes... --> Neutral
# batman flies through the flames... on the other side, the track dead ends at another tunnel... --> Negative
# gordon looks up in time to see batman latch the grappling gun into his belt shoot up, skirting the lip of the tunnel... 311 int. --> Negative
# train  continuous 311 batman jumps into the rear car fires his grappling gun at a ninjas leg, yanks him down... --> Negative
# ras glances back from the front car, but cant see clearly. --> Negative
# batman downs a ninja with an elbow to the head. --> Neutral
# leaps for the door between cars a ninja in the front car locks it smash ras turns to see batman at the rear door, glass falling from the window, hands around the ninjas throat... --> Negative
# ras al ghul you batman drops the ninja. --> Neutral
# leads up out of sight. --> Neutral
# 312 int. --> Neutral
# control room, water board  continuous 312 alarms the technician watches the blinking lights move close to the hub... the pressure gauge needle tips into the red continued continued 2 140. --> Negative
# earle what are you doing here, fox i seem to remember firing you. --> Negative
# continued continued 2 143. --> Positive
# fox might be something to do with my new job as head of wayne industries. --> Neutral
# off look didnt you get the memo earle stares at fox, hard. --> Negative
# earle whose authority fox points at waynes rolls royce idling nearby. --> Positive
# earle strides towards it. --> Neutral
# fox quietly smiles, turns to his work. --> Positive
# 319 int. --> Neutral
# rolls  continuous 319 earle is banging on the window. --> Neutral
# wayne rolls it down. --> Neutral
# earle you think you have authority to decide who runs this company, bruce wayne it is mycompany. --> Positive
# earle not anymore. --> Neutral
# wayne industries went public a week ago wayne --> Neutral
# and i bought most of the shares. --> Positive
# a controlling interest, in fact. --> Positive
# off look through various charitable foundations, trusts and so forth... --> Positive
# alfred is smiling in the front seat. --> Positive
# wayne contd look, its all a bit technical, but the important thing is.... --> Positive
# my companys future is secure. --> Positive
# earle is speechless. --> Neutral
# wayne smiles. --> Positive
# the rolls pulls away. --> Neutral
# 144. 320 ext. grounds, smoking ruins of wayne manor  day 320 workers sift through the smoking ruins, supervised by alfred. --> Negative
# 321 int. --> Neutral
# orangery  continuous 321 sootstained glass crunches underfoot as rachel picks her way through the smoking remnants of the greenhouse. --> Neutral
# 322 ext. --> Neutral
# disused kitchen garden  continuous 322 rachel finds wayne hammering a board across the disused well. --> Positive
# he looks up at her. --> Neutral
# she approaches. --> Neutral
# he turns to the well. --> Positive
# wayne do you remember the day i fell rachel of course. --> Neutral
# wayne looks down at the black gap yet to be covered. --> Neutral
# wayne as i lay there, i knew ... --> Neutral
# i could sense it... --> Neutral
# rachel what wayne that things would never be the same. --> Neutral
# rachel --> Neutral
# what did you find down there wayne picks up another board. --> Neutral
# wayne childhoods end. --> Neutral
# wayne places the board over over the gap. --> Neutral
# closing the well. --> Positive
# 323 ext. --> Neutral
# smoking ruins of wayne manor  moments later 323 wayne walks rachel past the ruins. --> Negative
# continued continued 2 145. --> Neutral
# rachel the day you left gotham... --> Neutral
# the day chill was murdered... --> Negative
# i said terrible things. --> Negative
# wayne true things. --> Positive
# you made me see that justice is about more than my own pain and anger. --> Negative
# rachel well, you proved me wrong. --> Negative
# wayne about what rachel your father would be proud of you. --> Positive
# just as i am. --> Neutral
# wayne looks at her, emotion rising. --> Neutral
# he takes rachel in his arms and they kiss, passionately... desperately. --> Positive
# they break, wayne looks into rachels eyes, hopeful. --> Positive
# but she gently shakes her head. --> Positive
# rachel contd soft between batman and bruce wayne, theres no room for me. --> Negative
# wayne rachel, this life i chose... --> Neutral
# i can give it up. --> Neutral
# rachel reaches up to his face with her hand. --> Positive
# rachel you didnt choose the life, bruce. --> Neutral
# it was thrust upon you, the way greatness often is. --> Neutral
# youve given this city hope now shes depending on you. --> Positive
# we all are. --> Neutral
# wayne looks at her. --> Neutral
# aching. --> Negative
# he nods. --> Neutral
# rachel contd goodbye, bruce. --> Neutral
# she walks away. --> Neutral
# stops. --> Negative
# turns. --> Neutral
# points at the ruins. --> Negative
# continued continued 3 146. --> Neutral
# rachel contd what will you do wayne looks at her. --> Neutral
# glorious purpose in his eyes. --> Positive
# wayne im going to rebuild it just the way it was. --> Neutral
# brick for brick. --> Neutral
# rachel nods. --> Neutral
# walks off. --> Neutral
# wayne stares after her. alone... but alfred is at waynes shoulder. --> Negative
# watching his gaze. --> Neutral
# alfred just the way it was, sir wayne turns to alfred. --> Neutral
# wayne yes, why they stroll, side by side, towards the smoking ruins. --> Negative
# alfred i thought we might take the opportunity of making some improvements to the foundation. --> Positive
# wayne in the south east corner alfred precisely , sir. --> Neutral
# dissolve to the irregular shadow of a bat symbol cast up onto turbulent clouds... and we are 324 ext. --> Neutral
# roof, police station  night 324 gordon sips coffee from a styrofoam cup. --> Neutral
# beside him an upturned spotlight with a metal stencil bolted to it. --> Neutral
# a dark fluttering, and batman is standing the other side of the spotlight. --> Neutral
# he reaches out, taps the stencil. --> Positive
# batman nice. --> Positive
# continued continued 2 147. --> Neutral
# gordon crushing his cup couldnt find any mob bosses to strap to the light. --> Negative
# gordon kills the searchlight. --> Negative
# the two men stand opposite each other in the dark. --> Neutral
# batman well, sergeant gordon its lieutenant , now. --> Positive
# commissioner loeb had to promote me. --> Positive
# and he had to disband the task force hunting you. --> Neutral
# amazing what saving a city can do for your image. --> Positive
# batman then things are better. --> Positive
# gordon nods youve started something bent cops running scared, hope on the streets... gordon leaves his sentence hanging between them. --> Positive
# batman but gordon --> Neutral
# but theres a lot of weirdness out there right now... --> Negative
# the narrows is lost ... we still havent picked up crane or half the inmates of arkham that he freed... --> Positive
# batman we will. --> Neutral
# gotham will return to normal. --> Neutral
# gordon will it what about escalation batman escalation gordon westart carrying semiautomatics, they buy automatics... --> Neutral
# westart wearing kevlar, they buy armorpiercing rounds... --> Neutral
# continued continued 3 148. --> Neutral
# batman and gordon leans closer to batman. --> Neutral
# points at him. --> Neutral
# gordon and... youre wearing a mask and jumping off rooftops... --> Neutral
# gordon fishes in his pocket. --> Neutral
# gordon contd take this guy... he pulls out a clear plastic evidence bag. --> Positive
# gordon contd ...armed robbery, double homicide... inside the clear plastic bag is a playing card. --> Positive
# gordon contd got a taste for theatrics, like you... gordon hands batman the bag. --> Positive
# gordon contd leaves a calling card. --> Neutral
# batman turns the card over. --> Neutral
# it is a joker. --> Positive
# batman ill look into it. --> Negative
# he steps up onto the balustrade. --> Neutral
# gordon looks at him. --> Neutral
# gordon i never said thank you. --> Negative
# batman looks out at the lights of gotham. --> Neutral
# cloak billowing around him. --> Neutral
# batman and youll never have to. --> Neutral
# batman drops from the rooftop, gliding on the night wind. --> Neutral
# gordon smiles. --> Positive
# he cant help it. --> Negative
# fade out continued continued 4 149. credits. --> Positive
# end. --> Neutral

# %% [markdown]
# 6. Character/Plot Relationship Analysis:
#
# Identify the relationships between characters and how they interact throughout the story.
#
# Expected Output: Visual or text representation of character interactions and dynamics.
#
# Example: “John and Sara share a complex relationship, moving from rivalry to friendship

# %%
import spacy
from collections import defaultdict

# %%
# Load spaCy's English model with dependency parsing capabilities
nlp = spacy.load('en_core_web_sm')

# %%
# Function to extract character names (PERSON entities) using spaCy's NER
def extract_characters(data):
    doc = nlp(data)
    characters = set()

    # Find all PERSON entities (assumed to be characters)
    for ent in doc.ents:
        if ent.label_ == "PERSON":
            characters.add(ent.text)

    return list(characters)

# %%
# Function to find character interactions based on subject-verb-object relationships
def character_relationships(data, characters):
    doc = nlp(data)
    relationships = defaultdict(list)

    # Iterate over each sentence and check for subject-verb-object involving characters
    for sentence in doc.sents:
        subject = None
        verb = None
        obj = None
        
        for token in sentence:
            # If the token is a character and it's a subject (nsubj), set it as the subject
            if token.dep_ == "nsubj" and token.text in characters:
                subject = token.text

            # If the token is a verb, set it as the action
            if token.pos_ == "VERB":
                verb = token.lemma_

            # If the token is a character and it's an object (dobj), set it as the object
            if token.dep_ == "dobj" and token.text in characters:
                obj = token.text
        
        # If both subject and object are characters, we have a relationship
        if subject and verb and obj:
            relationships[(subject, obj)].append(verb)

    return relationships

# %%
# Function to print character relationships with inferred actions
def print_relationships(relationships):
    for (subject, obj), actions in relationships.items():
        unique_actions = set(actions)  # Get unique actions for clarity
        action_description = ', '.join(unique_actions)
        print(f"{subject} and {obj} have the following interactions: {action_description}")

# %%
# Step 1: Extract character names
characters = extract_characters(data)

# %%
# Step 2: Analyze character relationships (based on subject-verb-object structure)
relationships = character_relationships(data, characters)

# %%
# Step 3: Print the relationships between characters with inferred actions
print("\nCharacter Relationships and Interactions:")
print_relationships(relationships)
# Out:
# Character Relationships and Interactions:
# wayne and wayne have the following interactions: grab, s
# bruce and alfred have the following interactions: alfre
# alfred and bruce have the following interactions: look
# chill and rachel have the following interactions: share
# wayne and wall have the following interactions: reveal
# wayne and rachel have the following interactions: watch, remember, walk
# earle and wayne have the following interactions: stare, walk
# gotham and wayne have the following interactions: watch
# wayne and earle have the following interactions: approach
# wayne and mr.earle have the following interactions: buy
# bruce and cloak have the following interactions: drop
# wayne and gordon have the following interactions: have
# rachel and bruce have the following interactions: say
# corridor and rachel have the following interactions: billow
# gordon and rachel have the following interactions: see, carry
# corridor and cloak have the following interactions: open
# roof and wall have the following interactions: blast
# alfred and rachel have the following interactions: arrange
# fogbound and ninjas have the following interactions: move
# rachel and gordon have the following interactions: come, drag, inject
# rachel and rachel have the following interactions: realize
# cloak and cloak have the following interactions: glide

# %% [markdown]
# 7. Coreference Resolution:
#
# Resolve pronouns to ensure consistent narration, making the text easier to follow.
# Expected Output: More readable text by replacing pronouns with the appropriate nouns.
#
# Example: Instead of “He went there,” it becomes “John went to the market.”

# %%
import spacy

# %%
# Load spaCy's English model
nlp = spacy.load('en_core_web_sm')

# %%
# Function to resolve pronouns manually based on the preceding entities
def resolve_coreferences(data):
    doc = nlp(data)
    resolved_text = data

    # Store the last seen named entity (assumed to be a character)
    last_person = None

    # Iterate over tokens and replace pronouns with the last seen character
    for token in doc:
        if token.ent_type_ == "PERSON":
            last_person = token.text  # Update the last seen character
        elif token.pos_ == "PRON" and token.text.lower() in ["he", "she", "him", "her"]:
            if last_person:
                resolved_text = resolved_text.replace(token.text, last_person)

    return resolved_text

# %%
# Resolve coreferences in the sample script
resolved_text = resolve_coreferences(data)

# %%
print("\nResolved Text:")
print(resolved_text)
